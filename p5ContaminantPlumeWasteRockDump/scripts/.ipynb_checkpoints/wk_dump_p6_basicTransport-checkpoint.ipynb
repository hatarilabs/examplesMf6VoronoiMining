# %%
#Basic lines for transport modeling
import flopy ## Org
import json, os ## Org
import numpy as np ## Org
import geopandas as gpd ## Org
import matplotlib.pyplot as plt ## Org
from mf6Voronoi.tools.cellWork import getLayCellElevTupleFromRaster, getLayCellElevTupleFromObs ## Org
# Out:
# C:\Users\saulm\anaconda3\Lib\site-packages\pyvista\examples\downloads.py:93: DeprecationWarning: support for supplying keyword arguments to pathlib.PurePath is deprecated and scheduled for removal in Python 3.14
#   Path(USER_DATA_PATH, exist_ok=True).mkdir()
# C:\Users\saulm\anaconda3\Lib\site-packages\pyvista\examples\downloads.py:98: UserWarning: Unable to access C:\Users\saulm\AppData\Local\pyvista_3\pyvista_3\Cache. Manually specify the PyVistaexamples cache with the PYVISTA_USERDATA_PATH environment variable.
#   warnings.warn(

# %%
# load simulation
simName = 'mf6Sim' ## Org
modelName = 'mf6Model' ## Org 
modelWs = os.path.abspath('../modelFiles') ## Org
sim = flopy.mf6.MFSimulation.load(sim_name=modelName, version='mf6', ## Org
                             exe_name='../bin/mf6.exe', ## <==== updated
                             
                             sim_ws=modelWs) ## Org
transWs  = os.path.abspath('../transFiles') ## Org
#change working directory
sim.set_sim_path(transWs) ## Org
sim.write_simulation(silent=True) ## Org
# Out:
# loading simulation...
#   loading simulation name file...
#   loading tdis package...
#   loading model gwf6...
#     loading package disv...
#     loading package ic...
#     loading package npf...
#     loading package sto...
#     loading package rch...
#     loading package evt...
#     loading package drn...
#     loading package ghb...
#     loading package oc...
#   loading solution package mf6model...

# %%
#list model names
sim.model_names ## Org
# Out:
# ['mf6model']

# %%
#select the flow model
gwf = sim.get_model('mf6model') ## Org

# %%
# open the json file
with open('../json/disvDict.json') as file: ## Org
    gridProps = json.load(file) ## Org

cell2d = gridProps['cell2d']           #cellid, cell centroid xy, vertex number and vertex id list ## Org
vertices = gridProps['vertices']       #vertex id and xy coordinates ## Org
ncpl = gridProps['ncpl']               #number of cells per layer ## Org
nvert = gridProps['nvert']             #number of verts ## Org
centroids=gridProps['centroids']       ## Org

# %%
#define the transport model ## Org
gwt = flopy.mf6.ModflowGwt(sim, ## Org
                           modelname='gwtModel', ## Org
                           save_flows=True) ## Org

# %%
#register solver for transport model
imsGwt = flopy.mf6.ModflowIms(sim, print_option='SUMMARY', ## Org 
                              outer_dvclose=1e-4, ## Org
                              inner_dvclose=1e-4, ## Org
                            #   outer_maximum=50, ## <=== updated
                            #   inner_maximum=30, ## <=== updated
                              linear_acceleration='BICGSTAB') ## Org
sim.register_ims_package(imsGwt,[gwt.name]) ## Org

# %%
# apply discretization to transport model
disv = flopy.mf6.ModflowGwtdisv(gwt,  ## Org 
                                nlay=gwf.modelgrid.nlay,  ## Org 
                                ncpl=ncpl,  ## Org 
                                top=gwf.modelgrid.top,  ## Org 
                                botm=gwf.modelgrid.botm,  ## Org 
                                nvert=nvert,  ## Org 
                                vertices=vertices,  ## Org 
                                cell2d=cell2d)  ## Org

# %%
#define starting concentrations
strtConc = np.zeros((gwf.modelgrid.nlay, ncpl), dtype=np.float32) ## Org 

interIx = flopy.utils.gridintersect.GridIntersect(gwf.modelgrid) ## Org 

#waste dump recharge
layCellTupleList, cellElevList = getLayCellElevTupleFromRaster(gwf, ## <===== inserted 
                                                               interIx,  ## <===== inserted
                                                               '../output/waterTable.tif',  ## <===== inserted
                                                               '../shp/wasteDump/wasteDump.shp')  ## <===== inserted

for layCell in layCellTupleList:   ## <===== inserted
    strtConc[layCell[0],layCell[1]] = 1200   ## <===== inserted

gwtIc = flopy.mf6.ModflowGwtic(gwt, strt=strtConc) ## Org
# Out:
# The cell 11204 has a elevation of 558.07 outside the model vertical domain
# The cell 11206 has a elevation of 558.26 outside the model vertical domain
# The cell 11207 has a elevation of 558.34 outside the model vertical domain
# The cell 11209 has a elevation of 558.42 outside the model vertical domain
# The cell 11210 has a elevation of 558.45 outside the model vertical domain
# The cell 11212 has a elevation of 558.44 outside the model vertical domain
# The cell 11213 has a elevation of 558.41 outside the model vertical domain
# The cell 11215 has a elevation of 558.31 outside the model vertical domain
# The cell 11353 has a elevation of 558.27 outside the model vertical domain
# The cell 11355 has a elevation of 558.40 outside the model vertical domain
# The cell 11357 has a elevation of 558.47 outside the model vertical domain
# The cell 11358 has a elevation of 558.54 outside the model vertical domain
# The cell 11360 has a elevation of 558.56 outside the model vertical domain
# The cell 11361 has a elevation of 558.55 outside the model vertical domain
# The cell 11363 has a elevation of 558.51 outside the model vertical domain
# The cell 11364 has a elevation of 558.41 outside the model vertical domain
# The cell 11517 has a elevation of 558.41 outside the model vertical domain
# The cell 11519 has a elevation of 558.53 outside the model vertical domain
# The cell 11520 has a elevation of 558.59 outside the model vertical domain
# The cell 11522 has a elevation of 558.65 outside the model vertical domain
# The cell 11523 has a elevation of 558.67 outside the model vertical domain
# The cell 11525 has a elevation of 558.65 outside the model vertical domain
# The cell 11526 has a elevation of 558.62 outside the model vertical domain
# The cell 11528 has a elevation of 558.51 outside the model vertical domain
# The cell 11667 has a elevation of 558.65 outside the model vertical domain
# The cell 11668 has a elevation of 558.75 outside the model vertical domain
# The cell 11670 has a elevation of 558.80 outside the model vertical domain
# The cell 11671 has a elevation of 558.85 outside the model vertical domain
# The cell 11673 has a elevation of 558.87 outside the model vertical domain
# The cell 11674 has a elevation of 558.85 outside the model vertical domain
# The cell 11676 has a elevation of 558.83 outside the model vertical domain
# The cell 11677 has a elevation of 558.71 outside the model vertical domain
# The cell 11820 has a elevation of 559.02 outside the model vertical domain
# The cell 11821 has a elevation of 559.02 outside the model vertical domain
# The cell 11823 has a elevation of 559.01 outside the model vertical domain
# The cell 11824 has a elevation of 558.96 outside the model vertical domain
# The cell 11972 has a elevation of 559.27 outside the model vertical domain
# The cell 11973 has a elevation of 559.30 outside the model vertical domain
# The cell 11975 has a elevation of 559.30 outside the model vertical domain
# The cell 11976 has a elevation of 559.33 outside the model vertical domain
# The cell 12123 has a elevation of 559.45 outside the model vertical domain
# The cell 12125 has a elevation of 559.49 outside the model vertical domain
# The cell 12126 has a elevation of 559.51 outside the model vertical domain
# The cell 12128 has a elevation of 559.55 outside the model vertical domain
# The cell 12272 has a elevation of 559.74 outside the model vertical domain
# The cell 12274 has a elevation of 559.80 outside the model vertical domain
# The cell 12275 has a elevation of 559.83 outside the model vertical domain
# The cell 12277 has a elevation of 559.98 outside the model vertical domain
# The cell 13018 has a elevation of 563.98 outside the model vertical domain
# The cell 13020 has a elevation of 564.00 outside the model vertical domain
# The cell 13021 has a elevation of 563.95 outside the model vertical domain
# The cell 13023 has a elevation of 563.73 outside the model vertical domain
# The cell 13162 has a elevation of 564.12 outside the model vertical domain
# The cell 13164 has a elevation of 564.10 outside the model vertical domain
# The cell 13165 has a elevation of 564.05 outside the model vertical domain
# The cell 13167 has a elevation of 563.86 outside the model vertical domain
# The cell 13314 has a elevation of 564.28 outside the model vertical domain
# The cell 13315 has a elevation of 564.24 outside the model vertical domain
# The cell 13317 has a elevation of 564.17 outside the model vertical domain
# The cell 13318 has a elevation of 564.03 outside the model vertical domain
# The cell 13460 has a elevation of 564.54 outside the model vertical domain
# The cell 13462 has a elevation of 564.48 outside the model vertical domain
# The cell 13463 has a elevation of 564.41 outside the model vertical domain
# The cell 13465 has a elevation of 564.26 outside the model vertical domain
# The cell 15959 has a elevation of 570.56 outside the model vertical domain
# The cell 15960 has a elevation of 570.54 outside the model vertical domain
# The cell 15962 has a elevation of 570.53 outside the model vertical domain
# The cell 15963 has a elevation of 570.50 outside the model vertical domain
# The cell 16104 has a elevation of 570.86 outside the model vertical domain
# The cell 16106 has a elevation of 570.80 outside the model vertical domain
# The cell 16107 has a elevation of 570.77 outside the model vertical domain
# The cell 16109 has a elevation of 570.73 outside the model vertical domain
# The cell 16260 has a elevation of 571.06 outside the model vertical domain
# The cell 16262 has a elevation of 570.97 outside the model vertical domain
# The cell 16263 has a elevation of 570.92 outside the model vertical domain
# The cell 16265 has a elevation of 570.87 outside the model vertical domain
# The cell 16405 has a elevation of 571.33 outside the model vertical domain
# The cell 16407 has a elevation of 571.20 outside the model vertical domain
# The cell 16408 has a elevation of 571.13 outside the model vertical domain
# The cell 16410 has a elevation of 571.06 outside the model vertical domain

# %%
fig = plt.figure(figsize=(12, 12)) ## Org 
ax = fig.add_subplot(1, 1, 1, aspect = 'equal') ## Org 
mapview = flopy.plot.PlotMapView(model=gwf,layer = 2) ## Org 

plot_array = mapview.plot_array(strtConc,masked_values=[-1e+30], cmap=plt.cm.summer) ## Org 
plt.colorbar(plot_array, shrink=0.75,orientation='horizontal', pad=0.08, aspect=50) ## Org

# %%
# set advection, dispersion
adv = flopy.mf6.ModflowGwtadv(gwt, scheme='UPSTREAM') ## Org 
dsp = flopy.mf6.ModflowGwtdsp(gwt, alh=1.0, ath1=0.1) ## Org 

#define mobile storage and transfer
porosity = 0.3 ## <==== updated 
sto = flopy.mf6.ModflowGwtmst(gwt, porosity=porosity) ## Org

# %%
#define sink and source package
sourcerecarray = [()] ## Org 
ssm = flopy.mf6.ModflowGwtssm(gwt, sources=sourcerecarray) ## Org

# %%
cncSpd = {} ## Org
cncSpd[0] = [] ## Org
for layCell in layCellTupleList: ## <===== inserted
    cncSpd[0].append([layCell[0],layCell[1],1200]) ## <===== inserted
    
cnc = flopy.mf6.ModflowGwtcnc(gwt,stress_period_data=cncSpd) ## Org
cnc.plot(mflay=2) ## Org
# Out:
# [<Axes: title={'center': ' cnc_0 location stress period 1 layer 3'}>]

# %%
obsList = []
nameList, obsLayCellList = getLayCellElevTupleFromObs(gwf, ## Org
                  interIx, ## Org
                  '../shp/wasteDump/piezometers.shp', ## <==== updated
                  'Name', ## <==== updated
                  'screenElev') ## <==== updated

for obsName, obsLayCell in zip(nameList, obsLayCellList): ## Org
    obsList.append((obsName,'concentration',obsLayCell[0]+1,obsLayCell[1]+1)) ## Org


obs = flopy.mf6.ModflowUtlobs( ## Org
    gwt,
    filename=gwt.name+'.obs', ## Org
    digits=10, ## Org
    print_input=True, ## Org
    continuous={gwt.name+'.obs.csv': obsList} ## Org
)
# Out:
# Working for cell 14012
# Well screen elev of 452.00 found at layer 6
# Working for cell 7673
# Well screen elev of 528.00 found at layer 5
# Working for cell 5061
# Well screen elev of 435.00 found at layer 6
# Working for cell 2682
# Well screen elev of 628.00 found at layer 4
# Working for cell 7804
# Well screen elev of 478.00 found at layer 6

# %%
#define output control
oc_gwt = flopy.mf6.ModflowGwtoc(gwt, ## Org
                                budget_filerecord='%s.cbc'%gwt.name, ## Org
                                concentration_filerecord='%s.ucn'%gwt.name, ## Org
                                saverecord=[('CONCENTRATION', 'LAST'), ('BUDGET', 'LAST')], ## Org
                                printrecord=[('CONCENTRATION', 'LAST'), ('BUDGET', 'LAST')], ## Org
                                )

# %%
pd = [ ## Org
    ("GWFHEAD", "../modelFiles/mf6Model.hds"), ## <===== updated
    ("GWFBUDGET", "../modelFiles/mf6Model.cbc"), ## <===== updated
]

fmi = flopy.mf6.ModflowGwtfmi(gwt, ## Org
                              flow_imbalance_correction=True, ## Org
                              packagedata=pd) ## Org

# %%
sim.write_simulation() ## Org
success, buff = sim.run_simulation() ## Org
# Out:
# writing simulation...
#   writing simulation name file...
#   writing simulation tdis package...
#   writing solution package ims_0...
#   writing model mf6model...
#     writing model name file...
#     writing package disv...
#     writing package ic...
#     writing package npf...
#     writing package sto...
#     writing package rcha_0...
#     writing package evta_0...
#     writing package drn_0...
#     writing package ghb_0...
#     writing package oc...
#   writing model gwtModel...
#     writing model name file...
#     writing package disv...
#     writing package ic...
#     writing package adv...
#     writing package dsp...
#     writing package mst...
#     writing package ssm...
#     writing package cnc_0...
# INFORMATION: maxbound in ('gwt6', 'cnc', 'dimensions') changed to 6140 based on size of stress_period_data
#     writing package obs_0...
#     writing package oc...
#     writing package fmi...
# FloPy is using the following executable to run the model: ..\bin\mf6.exe
#                                    MODFLOW 6
#                 U.S. GEOLOGICAL SURVEY MODULAR HYDROLOGIC MODEL
#                             VERSION 6.6.0 12/20/2024
#
#    MODFLOW 6 compiled Dec 31 2024 17:10:16 with Intel(R) Fortran Intel(R) 64
#    Compiler Classic for applications running on Intel(R) 64, Version 2021.7.0
#                              Build 20220726_000000
#
# This software has been approved for release by the U.S. Geological
# Survey (USGS). Although the software has been subjected to rigorous
# review, the USGS reserves the right to update the software as needed
# pursuant to further analysis and review. No warranty, expressed or
# implied, is made by the USGS or the U.S. Government as to the
# functionality of the software and related material nor shall the
# fact of release constitute any such warranty. Furthermore, the
# software is released on condition that neither the USGS nor the U.S.
# Government shall be held liable for any damages resulting from its
# authorized or unauthorized use. Also refer to the USGS Water
# Resources Software User Rights Notice for complete use, copyright,
# and distribution information.
#
#
#  MODFLOW runs in SEQUENTIAL mode
#
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2025/08/12 13:22:58
#
#  Writing simulation list file: mfsim.lst
#  Using Simulation name file: mfsim.nam
#
#     Solving:  Stress period:     1    Time step:     1
#     Solving:  Stress period:     1    Time step:     2
#     Solving:  Stress period:     1    Time step:     3
#     Solving:  Stress period:     1    Time step:     4
#     Solving:  Stress period:     1    Time step:     5
#     Solving:  Stress period:     1    Time step:     6
#     Solving:  Stress period:     1    Time step:     7
#     Solving:  Stress period:     1    Time step:     8
#     Solving:  Stress period:     1    Time step:     9
#     Solving:  Stress period:     1    Time step:    10
#
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2025/08/12 13:24:37
#  Elapsed run time:  1 Minutes, 38.699 Seconds
#
#
# WARNING REPORT:
#
#   1.  Simulation convergence failure occurred 1 time(s).
#  Normal termination of simulation.

# %%
concObj = gwt.output.concentration() ## Org
concObj.get_times() ## Org
# Out:
# [1576800000.0]

# %%
conc = concObj.get_data() ## Org
conc.shape ## Org
# Out:
# (11, 1, 22158)

# %%
transAoi = gpd.read_file('../shp/wasteDump/modelRefinement.shp') ## <===== updated
xMin, yMin, xMax, yMax = transAoi.bounds.iloc[0].values ## Org

# %%
mflay = 3 ## Org

# Plot the heads for a defined layer and boundary conditions
fig = plt.figure(figsize=(12,8))  ## Org
ax = fig.add_subplot(1, 1, 1, aspect='equal')  ## Org
modelmap = flopy.plot.PlotMapView(model=gwf)  ## Org

levels = np.linspace(0,conc.max()/2,num=10)  ## Org
quadmesh = modelmap.plot_bc('DRN', color='crimson')  ## Org

contour = modelmap.contour_array(conc[mflay],ax=ax,levels=levels,cmap='summer')  ## Org
ax.clabel(contour)  ## Org

linecollection = modelmap.plot_grid(linewidth=0.1, alpha=0.8, color='cyan', ax=ax)  ## Org

cellConc = modelmap.plot_array(conc[mflay],ax=ax,cmap='Blues')  ## Org

quadmesh = modelmap.plot_bc('DRN', color='slategrey')  ## Org

dump1 = modelmap.plot_shapefile('../shp/wasteDump/wasteDump.shp') ##<==== uncommented
piezo = modelmap.plot_shapefile('../shp/wasteDump/piezometers.shp', radius=10) ##<==== uncommented

ax.set_xlim(xMin-500,xMax+500)
ax.set_ylim(yMin-500,yMax+500)

plt.colorbar(cellConc, shrink=0.25) 

plt.show()

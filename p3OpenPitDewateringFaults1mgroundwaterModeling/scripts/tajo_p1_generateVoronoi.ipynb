# %% [markdown]
# ## Part 1 : Voronoi mesh generation

# %%
#!pip install -U mf6Voronoi

# %%
import warnings ## Org
warnings.filterwarnings('ignore') ## Org

import os, sys ## Org
import geopandas as gpd ## Org
from mf6Voronoi.geoVoronoi import createVoronoi ## Org
from mf6Voronoi.meshProperties import meshShape ## Org
from mf6Voronoi.utils import initiateOutputFolder, getVoronoiAsShp ## Org

# %%
#Create mesh object specifying the coarse mesh and the multiplier
vorMesh = createVoronoi(meshName='openPit',maxRef = 200, multiplier=2.5, overlapping=False) ## Org

#Open limit layers and refinement definition layers
vorMesh.addLimit('basin','../shp/local/aoi.shp') ## Org
vorMesh.addLayer('faults','../shp/faults_v2.shp',1) #<======= Insert
vorMesh.addLayer('river','../shp/river_basin.shp',50) ## Org
vorMesh.addLayer('pit','../shp/minePlan/pitShell.shp',50) ## Org 
vorMesh.addLayer('regionalFlow','../shp/local/regionalFlow.shp',50)

# %%
#Generate point pair array
vorMesh.generateOrgDistVertices() ## Org

#Generate the point cloud and voronoi
vorMesh.createPointCloud() ## Org
vorMesh.generateVoronoi() ## Org
# Out:
#     <link href="https://fonts.googleapis.com/css2?family=Anton&display=swap" rel="stylesheet">
#
#     <style>
#         .styled-text {
#         font-family: 'Anton', Impact, sans-serif;
#         font-size: 32px;
#         font-weight: bold;
#         font-style: italic;
#         }
#     </style>
#
#     <div>
#     <a href="https://hatarilabs.com" target="_blank">
#             <img src="https://olivosbellaterra.com/static/img/png/hatarilabs.png" alt="Hatarilabs" width="200" height="200"></a>
#             <p class="styled-text">mf6Voronoi will have a web version in 2028</p>
#     </div>
#
#     <table border="0px">
#     <tbody>
#     <tr>
#         <td><h3>Follow us:</h3></td>
#         <td><a href="https://www.linkedin.com/company/hatarilabs" target="_blank">
#             <img src="https://olivosbellaterra.com/static/img/svg/icons8-linkedin.svg" alt="Hatarilabs"></a></td>
#         <td><a href="https://www.facebook.com/hatarilabs" target="_blank">
#             <img src="https://olivosbellaterra.com/static/img/svg/icons8-facebook.svg" alt="Hatarilabs"></a></td>
#         <td><a href="https://www.instagram.com/hatarilabs" target="_blank">
#             <img src="https://olivosbellaterra.com/static/img/svg/icons8-instagram.svg" alt="Hatarilabs"></a></td>
#         <td><a href="https://www.youtube.com/hatarilabs" target="_blank">
#             <img src="https://olivosbellaterra.com/static/img/svg/icons8-youtube.svg" alt="Hatarilabs"></a></td>
#         <td><a href="https://www.tiktok.com/@_hatarilabs" target="_blank">
#             <img src="https://olivosbellaterra.com/static/img/svg/icons8-tiktok.svg" alt="Hatarilabs"></a></td>
#         <td><a href="https://x.com/hatarilabs" target="_blank">
#             <img src="https://olivosbellaterra.com/static/img/svg/icons8-twitterx.svg" alt="Hatarilabs"></a></td>
#     </tr>
#     </tbody>
#     </table>
# /--------Layer faults discretization-------/
# Progressive cell size list: [1, 3.5, 9.75, 25.375, 64.4375, 162.09375] m.
#
# /--------Layer river discretization-------/
# Progressive cell size list: [50, 175.0] m.
#
# /--------Layer pit discretization-------/
# Progressive cell size list: [50, 175.0] m.
#
# /--------Layer regionalFlow discretization-------/
# Progressive cell size list: [50, 175.0] m.
#
# /----Sumary of points for voronoi meshing----/
# Distributed points from layers: 4
# Points from layer buffers: 26874
# Points from max refinement areas: 384
# Points from min refinement areas: 629
# Total points inside the limit: 35446
# /--------------------------------------------/
#
# Time required for point generation: 15.48 seconds
#
#
# /----Generation of the voronoi mesh----/
#
# Time required for voronoi generation: 5.12 seconds

# %%
#Uncomment the next two cells if you have strong differences on discretization or you have encounter an FORTRAN error while running MODFLOW6

# %%
vorMesh.checkVoronoiQuality(threshold=0.01)
# Out:
# /----Performing quality verification of voronoi mesh----/
# Short side on polygon: 35445 with length = 0.00123
# Short side on polygon: 35445 with length = 0.00123
# Short side on polygon: 35445 with length = 0.00123
# Short side on polygon: 35445 with length = 0.00123
# Short side on polygon: 35445 with length = 0.00538
# Short side on polygon: 35445 with length = 0.00538
# Short side on polygon: 35445 with length = 0.00123
# Short side on polygon: 35445 with length = 0.00123
# Short side on polygon: 35445 with length = 0.00793
# Short side on polygon: 35445 with length = 0.00793
# Short side on polygon: 35445 with length = 0.00123
# Short side on polygon: 35445 with length = 0.00123
# Short side on polygon: 35445 with length = 0.00793
# Short side on polygon: 35445 with length = 0.00793
# Short side on polygon: 35445 with length = 0.00123
# Short side on polygon: 35445 with length = 0.00123
# Short side on polygon: 35445 with length = 0.00793
# Short side on polygon: 35445 with length = 0.00793
# Short side on polygon: 35445 with length = 0.00123
# Short side on polygon: 35445 with length = 0.00123
# Short side on polygon: 35445 with length = 0.00793
# Short side on polygon: 35445 with length = 0.00793
# Short side on polygon: 35445 with length = 0.00995
# Short side on polygon: 35445 with length = 0.00995
# Short side on polygon: 35445 with length = 0.00525
# Short side on polygon: 35445 with length = 0.00525
# Short side on polygon: 35445 with length = 0.00793
# Short side on polygon: 35445 with length = 0.00793
# Short side on polygon: 35445 with length = 0.00995
# Short side on polygon: 35445 with length = 0.00995
# Short side on polygon: 35445 with length = 0.00698
# Short side on polygon: 35445 with length = 0.00698
# Short side on polygon: 35445 with length = 0.00512
# Short side on polygon: 35445 with length = 0.00107
# Short side on polygon: 35445 with length = 0.00107
# Short side on polygon: 35445 with length = 0.00793
# Short side on polygon: 35445 with length = 0.00512
# Short side on polygon: 35445 with length = 0.00512
# Short side on polygon: 35445 with length = 0.00793
# Short side on polygon: 35445 with length = 0.00512
# Short side on polygon: 35445 with length = 0.00248
# Short side on polygon: 35445 with length = 0.00380
# Short side on polygon: 35445 with length = 0.00380
# Short side on polygon: 35445 with length = 0.00248
# Short side on polygon: 35445 with length = 0.00512
# Short side on polygon: 35445 with length = 0.00512
# Short side on polygon: 35445 with length = 0.00512
# Short side on polygon: 35445 with length = 0.00512
# Short side on polygon: 35445 with length = 0.00000
# Short side on polygon: 35445 with length = 0.00000
# Short side on polygon: 35445 with length = 0.00698
# Short side on polygon: 35445 with length = 0.00698
# Short side on polygon: 35445 with length = 0.00666
# Short side on polygon: 35445 with length = 0.00512
# Short side on polygon: 35445 with length = 0.00793
# Short side on polygon: 35445 with length = 0.00793
# Short side on polygon: 35445 with length = 0.00512
# Short side on polygon: 35445 with length = 0.00512
# Short side on polygon: 35445 with length = 0.00512
# Short side on polygon: 35445 with length = 0.00380
# Short side on polygon: 35445 with length = 0.00380
# Short side on polygon: 35445 with length = 0.00512
# Short side on polygon: 35445 with length = 0.00512
# Short side on polygon: 35445 with length = 0.00512
# Short side on polygon: 35445 with length = 0.00512
# Short side on polygon: 35445 with length = 0.00698
# Short side on polygon: 35445 with length = 0.00666
# Short side on polygon: 35445 with length = 0.00698
# Short side on polygon: 35445 with length = 0.00793
# Short side on polygon: 35445 with length = 0.00380
# Short side on polygon: 35445 with length = 0.00380
# Short side on polygon: 35445 with length = 0.00793
# Short side on polygon: 35445 with length = 0.00512
# Short side on polygon: 35445 with length = 0.00512
# Short side on polygon: 35445 with length = 0.00512
# Short side on polygon: 35445 with length = 0.00512
# Short side on polygon: 35445 with length = 0.00636
# Short side on polygon: 35445 with length = 0.00268
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00894
# Short side on polygon: 35445 with length = 0.00894
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00636
# Short side on polygon: 35445 with length = 0.00221
# Short side on polygon: 35445 with length = 0.00221
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00939
# Short side on polygon: 35445 with length = 0.00268
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00939
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00449
# Short side on polygon: 35445 with length = 0.00232
# Short side on polygon: 35445 with length = 0.00449
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00232
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00939
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00232
# Short side on polygon: 35445 with length = 0.00939
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00232
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00703
# Short side on polygon: 35445 with length = 0.00703
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00232
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00232
# Short side on polygon: 35445 with length = 0.00939
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00939
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00293
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00293
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00639
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00639
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00633
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00250
# Short side on polygon: 35445 with length = 0.00750
# Short side on polygon: 35445 with length = 0.00750
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00514
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00514
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00514
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00514
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00514
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00514
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00514
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00149
# Short side on polygon: 35445 with length = 0.00514
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00149
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00108
# Short side on polygon: 35445 with length = 0.00367
# Short side on polygon: 35445 with length = 0.00367
# Short side on polygon: 35445 with length = 0.00762
# Short side on polygon: 35445 with length = 0.00762
# Short side on polygon: 35445 with length = 0.00367
# Short side on polygon: 35445 with length = 0.00367
# Short side on polygon: 35445 with length = 0.00102
# Short side on polygon: 35445 with length = 0.00102
# Short side on polygon: 35445 with length = 0.00102
# Short side on polygon: 35445 with length = 0.00102
# Short side on polygon: 35445 with length = 0.00102
# Short side on polygon: 35445 with length = 0.00102
# Short side on polygon: 35445 with length = 0.00102
# Short side on polygon: 35445 with length = 0.00031
# Short side on polygon: 35445 with length = 0.00102
# Short side on polygon: 35445 with length = 0.00031
# Short side on polygon: 35445 with length = 0.00688
# Short side on polygon: 35445 with length = 0.00102
# Short side on polygon: 35445 with length = 0.00102
# Short side on polygon: 35445 with length = 0.00688
# Short side on polygon: 35445 with length = 0.00102
# Short side on polygon: 35445 with length = 0.00102
# Short side on polygon: 35445 with length = 0.00584
# Short side on polygon: 35445 with length = 0.00225
# Short side on polygon: 35445 with length = 0.00584
# Short side on polygon: 35445 with length = 0.00225
# Short side on polygon: 35445 with length = 0.00367
# Short side on polygon: 35445 with length = 0.00367
# Short side on polygon: 35445 with length = 0.00102
# Short side on polygon: 35445 with length = 0.00730
# Short side on polygon: 35445 with length = 0.00133
# Short side on polygon: 35445 with length = 0.00730
# Short side on polygon: 35445 with length = 0.00646
# Short side on polygon: 35445 with length = 0.00102
# Short side on polygon: 35445 with length = 0.00646
# Short side on polygon: 35445 with length = 0.00030
# Short side on polygon: 35445 with length = 0.00133
# Short side on polygon: 35445 with length = 0.00030
# Short side on polygon: 35445 with length = 0.00102
# Short side on polygon: 35445 with length = 0.00102
# Short side on polygon: 35445 with length = 0.00030
# Short side on polygon: 35445 with length = 0.00030
# Short side on polygon: 35445 with length = 0.00133
# Short side on polygon: 35445 with length = 0.00133
# Short side on polygon: 35445 with length = 0.00573
# Short side on polygon: 35445 with length = 0.00573
# Short side on polygon: 35445 with length = 0.00133
# Short side on polygon: 35445 with length = 0.00133
# Short side on polygon: 35445 with length = 0.00133
# Short side on polygon: 35445 with length = 0.00133
# Short side on polygon: 35445 with length = 0.00133
# Short side on polygon: 35445 with length = 0.00807
# Short side on polygon: 35445 with length = 0.00807
# Short side on polygon: 35445 with length = 0.00133
# Short side on polygon: 35445 with length = 0.00367
# Short side on polygon: 35445 with length = 0.00367
# Short side on polygon: 35445 with length = 0.00428
# Short side on polygon: 35445 with length = 0.00428
# Short side on polygon: 35445 with length = 0.00117
# Short side on polygon: 35445 with length = 0.00117
# Short side on polygon: 35445 with length = 0.00117
# Short side on polygon: 35445 with length = 0.00117
# Short side on polygon: 35445 with length = 0.00807
# Short side on polygon: 35445 with length = 0.00807
# Short side on polygon: 35445 with length = 0.00426
# Short side on polygon: 35445 with length = 0.00426
# Short side on polygon: 35445 with length = 0.00851
# Short side on polygon: 35445 with length = 0.00851
# Short side on polygon: 35445 with length = 0.00807
# Short side on polygon: 35445 with length = 0.00807
# Short side on polygon: 35445 with length = 0.00924
# Short side on polygon: 35445 with length = 0.00924
# Short side on polygon: 35445 with length = 0.00807
# Short side on polygon: 35445 with length = 0.00807
# Short side on polygon: 35445 with length = 0.00980
# Short side on polygon: 35445 with length = 0.00980
# Short side on polygon: 35445 with length = 0.00807
# Short side on polygon: 35445 with length = 0.00807
# Short side on polygon: 35445 with length = 0.00031
# Short side on polygon: 35445 with length = 0.00031
# Short side on polygon: 35445 with length = 0.00924
# Short side on polygon: 35445 with length = 0.00924
# Short side on polygon: 35445 with length = 0.00888
# Short side on polygon: 35445 with length = 0.00888
# Short side on polygon: 35445 with length = 0.00980
# Short side on polygon: 35445 with length = 0.00980
# Short side on polygon: 35445 with length = 0.00924
# Short side on polygon: 35445 with length = 0.00513
# Short side on polygon: 35445 with length = 0.00924
# Short side on polygon: 35445 with length = 0.00513
# Short side on polygon: 35445 with length = 0.00031
# Short side on polygon: 35445 with length = 0.00031
# Short side on polygon: 35445 with length = 0.00408
# Short side on polygon: 35445 with length = 0.00408
# Short side on polygon: 35445 with length = 0.00980
# Short side on polygon: 35445 with length = 0.00031
# Short side on polygon: 35445 with length = 0.00980
# Short side on polygon: 35445 with length = 0.00031
# Short side on polygon: 35445 with length = 0.00198
# Short side on polygon: 35445 with length = 0.00983
# Short side on polygon: 35445 with length = 0.00198
# Short side on polygon: 35445 with length = 0.00983
# Short side on polygon: 35445 with length = 0.00389
# Short side on polygon: 35445 with length = 0.00983
# Short side on polygon: 35445 with length = 0.00983
# Short side on polygon: 35445 with length = 0.00389
# Short side on polygon: 35445 with length = 0.00198
# Short side on polygon: 35445 with length = 0.00198
# Short side on polygon: 35445 with length = 0.00983
# Short side on polygon: 35445 with length = 0.00983
# Short side on polygon: 35445 with length = 0.00983
# Short side on polygon: 35445 with length = 0.00983
# Short side on polygon: 35445 with length = 0.00826
# Short side on polygon: 35445 with length = 0.00826

# %%
vorMesh.fixVoronoiShortSides()
vorMesh.generateVoronoi()
vorMesh.checkVoronoiQuality(threshold=0.01)
# Out:
# /----Generation of the voronoi mesh----/
#
# Time required for voronoi generation: 5.67 seconds
#
#
# /----Performing quality verification of voronoi mesh----/
# Your mesh has no edges shorter than your threshold

# %%
#Export generated voronoi mesh
initiateOutputFolder('../output') ## Org
getVoronoiAsShp(vorMesh.modelDis, shapePath='../output/'+vorMesh.modelDis['meshName']+'.shp') ## Org
# Out:
# The output folder ../output exists and has been cleared
#
# /----Generation of the voronoi shapefile----/
#
# Time required for voronoi shapefile: 10.76 seconds

# %%
# Show the resulting voronoi mesh

#open the mesh file
mesh=gpd.read_file('../output/'+vorMesh.modelDis['meshName']+'.shp') ## Org
#plot the mesh
mesh.plot(figsize=(35,25), fc='crimson', alpha=0.3, ec='teal') ## Org
# Out:
# <Axes: >

# %% [markdown]
# ## Part 2 generate disv properties

# %%
# open the mesh file
mesh=meshShape('../output/'+vorMesh.modelDis['meshName']+'.shp') ## Org

# %%
# get the list of vertices and cell2d data
gridprops=mesh.get_gridprops_disv() ## Org
# Out:
# Creating a unique list of vertices [[x1,y1],[x2,y2],...]
# 100%|█████████████████████████████████████████████████████████████████████████| 35685/35685 [00:02<00:00, 12119.34it/s]
# Extracting cell2d data and grid index
# 100%|██████████████████████████████████████████████████████████████████████████| 35685/35685 [00:17<00:00, 2097.42it/s]

# %%
#create folder
initiateOutputFolder('../json') ## Org

#export disv
mesh.save_properties('../json/disvDict.json') ## Org
# Out:
# The output folder ../json exists and has been cleared
